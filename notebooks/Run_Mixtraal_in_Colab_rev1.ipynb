# %% [markdown]
# <a href="https://colab.research.google.com/github/abalvet/do-chatbots-dream-of-linguistics/blob/main/notebooks/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mixtral in Colab
#
# Welcome! In this notebook you can run [Mixtral8x7B-Instruct](https://huggingface.co/mistralai/Mixtral-8x7B-v0.1) with decent generation speed **right in Google Colab or on a consumer-grade GPU**. This was made possible by quantizing the original model in mixed precision and implementing a MoE-specific offloading strategy.
#
# To learn more, read our [tech report](https://arxiv.org/abs/2312.17238) or check out the [repo](https://github.com/dvmazur/mixtral-offloading) on GitHub.

# %% [markdown]
# One will need approximately 16 GB of VRAM and 11 GB of RAM to run this notebook and generate somewhat long texts.
#
#
# <details>
#
# <summary>How to balance between RAM and GPU VRAM usage</summary>
#
# You can balance between RAM and GPU VRAM usage by changing <code>offload_per_layer</code> variable in the <a href="#scrollTo=_mIpePTMFyRY&line=10&uniqifier=1">Initialize model</a> section. Increasing <code>offload_per_layer</code> will decrease GPU VRAM usage, increase RAM usage and decrease generation speed. Decreasing <code>offload_per_layer</code> will have the opposite effect.
#
# Note that this notebook should run normally in Google Colab with <code>offload_per_layer = 4</code>, but may crush with other values. However, if you run this somewhere else, you're free to play with this variable.
# </details>

# %% [markdown]
# ## Install and import libraries

# %%
# fix numpy in colab
import numpy
from IPython.display import clear_output

# fix triton in colab
# !export LC_ALL="en_US.UTF-8"
# !export LD_LIBRARY_PATH="/usr/lib64-nvidia"
# !export LIBRARY_PATH="/usr/local/cuda/lib64/stubs"
# !ldconfig /usr/lib64-nvidia

# !git clone https://github.com/dvmazur/mixtral-offloading.git --quiet
# !cd mixtral-offloading && pip install -q -r requirements.txt
# !huggingface-cli download lavawolfiee/Mixtral-8x7B-Instruct-v0.1-offloading-demo --quiet --local-dir Mixtral-8x7B-Instruct-v0.1-offloading-demo

clear_output()

# %%
import sys

sys.path.append("mixtral-offloading")
import torch
from torch.nn import functional as F
from hqq.core.quantize import BaseQuantizeConfig
from huggingface_hub import snapshot_download
from IPython.display import clear_output
from tqdm.auto import trange
from transformers import AutoConfig, AutoTokenizer
from transformers.utils import logging as hf_logging

from src.build_model import OffloadConfig, QuantConfig, build_model

# %% [markdown]
# ## Initialize model

# %%
model_name = "mistralai/Mixtral-8x7B-Instruct-v0.1"
quantized_model_name = "lavawolfiee/Mixtral-8x7B-Instruct-v0.1-offloading-demo"
state_path = "Mixtral-8x7B-Instruct-v0.1-offloading-demo"

config = AutoConfig.from_pretrained(quantized_model_name)

device = torch.device("cuda:0")

##### Change this to 5 if you have only 12 GB of GPU VRAM #####
offload_per_layer = 4
# offload_per_layer = 5
###############################################################

num_experts = config.num_local_experts

offload_config = OffloadConfig(
    main_size=config.num_hidden_layers * (num_experts - offload_per_layer),
    offload_size=config.num_hidden_layers * offload_per_layer,
    buffer_size=4,
    offload_per_layer=offload_per_layer,
)


attn_config = BaseQuantizeConfig(
    nbits=4,
    group_size=64,
    quant_zero=True,
    quant_scale=True,
)
attn_config["scale_quant_params"]["group_size"] = 256


ffn_config = BaseQuantizeConfig(
    nbits=2,
    group_size=16,
    quant_zero=True,
    quant_scale=True,
)
quant_config = QuantConfig(ffn_config=ffn_config, attn_config=attn_config)


model = build_model(
    device=device,
    quant_config=quant_config,
    offload_config=offload_config,
    state_path=state_path,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Loading experts:   0%|          | 0/32 [00:00<?, ?it/s]

# %% [markdown]
# ## Run the model

# %%
from transformers import TextStreamer


tokenizer = AutoTokenizer.from_pretrained(model_name)
streamer = TextStreamer(tokenizer, skip_prompt=True, skip_special_tokens=True)
past_key_values = None
sequence = None

seq_len = 0
while True:
  print("User: ", end="")
  user_input = input()
  print("\n")

  user_entry = dict(role="user", content=user_input)
  input_ids = tokenizer.apply_chat_template([user_entry], return_tensors="pt").to(device)

  if past_key_values is None:
    attention_mask = torch.ones_like(input_ids)
  else:
    seq_len = input_ids.size(1) + past_key_values[0][0][0].size(1)
    attention_mask = torch.ones([1, seq_len - 1], dtype=torch.int, device=device)

  print("Mixtral: ", end="")
  result = model.generate(
    input_ids=input_ids,
    attention_mask=attention_mask,
    past_key_values=past_key_values,
    streamer=streamer,
    do_sample=True,
    temperature=0.9,
    top_p=0.9,
    max_new_tokens=512,
    pad_token_id=tokenizer.eos_token_id,
    return_dict_in_generate=True,
    output_hidden_states=True,
  )
  print("\n")

  sequence = result["sequences"]
  past_key_values = result["past_key_values"]
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# User: Je veux travailler sur la morphologie du français. Connais-tu les travaux en morphologie lexématique en français, par des auteurs comme Fiammetta Namer, Georgette Dal ou Bernard Fradin?
#
#
# Mixtral: Je suis désolé, mais je n'ai pas de connaissance personnelle des chercheurs et de leur travail en particulier. Cependant, je peux vous dire que Fiammetta Namer, Georgette Dal et Bernard Fradin sont des chercheurs et des universitaires reconnus dans le domaine de la linguistique et de la linguistique computationnelle, respectivement en France et en Belgique.
#
# Fiammetta Namer est spécialisée en linguistique française, en particulier en morphologie lexicale et en acquisition du langage. Georgette Dal a travaillé sur la morphologie verbale et la sémantique lexicale en français, tandis que Bernard Fradin est connu pour ses travaux en linguistique computationnelle et en traitement automatique des langues, y compris en morphologie.
#
# Il est possible de trouver leurs publications et travaux en effectuant des recherches dans des bases de données académiques telles que Google Scholar, ResearchGate ou Academia.edu. Vous pouvez également consulter des revues spécialisées dans le domaine de la linguistique pour voir si leurs travaux y ont été publiés.
#
#
# User: Je veux travailler sur les Règles de Construction de Lexèmes, c'est à dire analyser la structure des mots construits par dérivation morphologique, en particulier. Sais-tu identifier la règle de construction de mots comme ORANGEADE ou CITRONNADE, en dégageant une base (avec sa catégorie grammaticale et son sens) et un suffixe, en donnant une glose du sens du lexème dérivé?
#
#
# Mixtral: Oui, je peux vous aider avec cela.
#
# Le mot "orangeade" est un dérivé du mot "orange" avec le suffixe "-ade". Dans ce cas, la base est le nom "orange" (qui est ici un fruit, donc un nom commun) et le suffixe "-ade" est un suffixe qui sert à former des noms qui désignent une boisson ou une préparation à base de ce fruit. Ainsi, une orangeade est une boisson préparée à base de jus d'orange.
#
# De même, le mot "citronnade" est un dérivé du mot "citron" avec le même suffixe "-ade". Dans ce cas, la base est le nom "citron" (qui est ici un fruit, donc un nom commun) et le suffixe "-ade" est un suffixe qui sert à former des noms qui désignent une boisson ou une préparation à base de ce fruit. Ainsi, une citronnade est une boisson préparée à base de jus de citron.
#
# En donnant une glose du sens du lexème dérivé, on peut dire que "orangeade" et "citronnade" sont des noms communs qui désignent une boisson préparée à base de jus d'orange ou de citron respectivement.
#
#
# User: Peux-tu faire la même chose pour les mots GÊNANCE et ENERVANCE?
#
#
# Mixtral: Bien sûr, je peux vous aider avec cela.
#
# Les mots "gênance" et "enervance" sont des formations morphologiques qui suivent une règle de dérivation bien établie en français.
#
# Le mot "gênance" est dérivé du verbe "gêner" avec le suffixe "-ance". Dans ce cas, la base est le verbe "gêner" (qui est ici un verbe d'action) et le suffixe "-ance" sert à former des noms qui désignent un état, un processus ou une qualité abstraite liée au verbe. Ainsi, la gênance est l'état de gêner ou d'être gêné.
#
# Le mot "enervance" est un néologisme qui n'est pas attesté dans la langue française standard, mais on peut en déduire le sens en appliquant la même règle de dérivation. Dans ce cas, la base est le verbe "enervé" (qui est ici un verbe d'action) et le suffixe "-ance" sert à former des noms qui désignent un état, un processus ou une qualité abstraite liée au verbe. Ainsi, l'enervance serait l'état d'être enervé ou surexcité.
#
# En donnant une glose du sens du lexème dérivé, on peut dire que "gênance" est un nom commun qui désigne un état de gêne ou de gêner et "enervance" est un néologisme qui désigne un état d'enervement ou de surexcitation.
#
#
# User: Saurais-tu me donner une Règle de Construction de Lexème qui explicite quelles unités (avec leur catégorie grammaticale et une indication de sens) se composent pour donner la forme dérivée en -ance?
#
#
# Mixtral: Oui, je peux vous donner une règle de construction de lexème pour les mots dérivés en "-ance".
#
# La règle de construction de lexème pour les mots dérivés en "-ance" est la suivante :
#
# Unités :
#
# * Base : un verbe ou un adjectif (catégorie grammaticale : verbe ou adjectif)
# * Suffixe : "-ance" (catégorie grammaticale : suffixe)
#
# Sens :
#
# * Le sens du lexème dérivé en "-ance" est un nom qui désigne un état, un processus ou une qualité abstraite liée au sens de la base.
#
# Exemple :
#
# * Pour le mot "gênance", la base est le verbe "gêner" et le suffixe est "-ance". Le sens du lexème dérivé est un nom qui désigne un état de gêne ou de gêner.
#
# Forme :
#
# * La forme du lexème dérivé en "-ance" est obtenue en ajoutant le suffixe "-ance" à la fin de la base.
#
# Note :
#
# * Il existe également le suffixe "-ance" féminin "-ance" qui sert à former des noms qui désignent un état, un processus ou une qualité abstraite liée à un adjectif. Par exemple, "douceur" est dérivé de "doux" avec le suffixe "-ure".
#
# En résumé, la règle de construction de lexème pour les mots dérivés en "-ance" est une règle qui consiste à ajouter le suffixe "-ance" à la fin d'une base qui est un verbe ou un adjectif pour former un nom qui désigne un état, un processus ou une qualité abstraite liée au sens de la base.
#
#
# User: Ok, je voudrais que tu exprimes une règle générale, comme celle-ci: V [action] + -ance -> N [état/résultat de l'action]. Adapte-la règle pour envisager le cas où la dérivation part de l'adjectif en -ant, pour aboutir au nom en -ance.
#
#
# Mixtral: Bien sûr, voici une règle générale pour les mots dérivés en "-ance" :
#
# V [action] / A [état] + -ance -> N [état/résultat de l'action]
#
# Cette règle indique que la base du mot dérivé en "-ance" peut être un verbe ou un adjectif qui exprime une action ou un état. Lorsque la base est un verbe, le sens du lexème dérivé est un nom qui désigne un état, un processus ou une qualité abstraite liée à l'action exprimée par le verbe. Lorsque la base est un adjectif, le sens du lexème dérivé est un nom qui désigne un état, un processus ou une qualité abstraite liée à l'état exprimé par l'adjectif.
#
# Dans le cas où la dérivation part de l'adjectif en -ant, la règle de construction de lexème est la suivante :
#
# A [état] + -ance -> N [état/résultat de l'état]
#
# Cette règle indique que la base du mot dérivé en "-ance" est un adjectif qui exprime un état. Le sens du lexème dérivé est un nom qui désigne un état, un processus ou une qualité abstraite liée à l'état exprimé par l'adjectif.
#
# Par exemple, pour le mot "gênant", la base est l'adjectif "gênant" et le suffixe est "-ance". Le sens du lexème dérivé est un nom qui désigne un état de gêne ou de gêner.
#
#
# User: Ok, disons que la règle RCL serait: A [état] + -ance -> N [état/résultat de l'état]. Saurais-tu inventer un Nom en -ance qui n'existe pas en français, à partir de cette règle?
#
#
# Mixtral: Bien sûr, je peux inventer un Nom en "-ance" qui n'existe pas en français en utilisant la règle RCL que vous avez fournie : A [état] + -ance -> N [état/résultat de l'état].
#
# Par exemple, à partir de l'adjectif "émerveillant", on peut dériver le Nom "émerveillance" en suivant la règle. Dans ce cas, la base est l'adjectif "émerveillant" qui exprime un état d'émerveillement. Le suffixe "-ance" sert à former un nom qui désigne un état, un processus ou une qualité abstraite liée à l'état d'émerveillement.
#
# Ainsi, le lexème "émerveillance" est un nom qui désigne un état, un processus ou une qualité abstraite liée à l'état d'émerveillement.
#
# Il convient de noter que ce terme n'existe pas en français standard, mais qu'il peut être utilisé dans un contexte particulier, comme dans un texte littéraire ou dans une conversation informelle.
#
#
# User:
